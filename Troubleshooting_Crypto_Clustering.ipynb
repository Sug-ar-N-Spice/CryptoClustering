# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
## later in code 
    #added import hvplot.pandas as pd to plot the line also tried import matplotlib.pyplot as plt
    #to better understand the differences and purpose of each import 
     #dependency will NOT be added here due to error code 
            # It seems like you're encountering an error because you're trying to use hvplot.pandas.read_csv instead of pd.read_csv to read the CSV file into a Pandas DataFrame.
            # To resolve this issue, you should use pd.read_csv from the pandas library to read the CSV file. Here's the corrected code snippet for loading the data into a Pandas DataFrame with the index set to the "coin_id" column:
            # import pandas as pd
            # # Load the data into a Pandas DataFrame and make the index the "coin_id" column
            # market_data_df = pd.read_csv("Resources/crypto_market_data.csv", index_col="coin_id")
            # # Display sample data
            # market_data_df.head(10)
            # By using pd.read_csv, you should be able to load the data successfully into a Pandas DataFrame. Let me know if you need further assistance or have any more question

# %%
# Load the data into a Pandas DataFrame and make the index the "coin_id" column.
## this was already provided - instructions in homework #2
market_data_df = pd.read_csv("Resources/crypto_market_data.csv", index_col="coin_id")
# Display sample data
market_data_df.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
market_data_df.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
            # from https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
            ## then put data frame i have 
            # scaler = StandardScaler()
            # print(scaler.fit(data))
            ## standard scaler makes it between 0 and 1 
        #scaler was provided in import StandardScaler()
scaled_data=StandardScaler().fit_transform(market_data_df)
        # maybe this would have been better need to ask Sean?? seems redundant scaled_data=scaler.fit_transform(market_data_df[["price_change_percentage_24h", "price_change_percentage_7d",
                #                 "price_change_percentage_14d", "price_change_percentage_30d",
                #                 "price_change_percentage_60d", "price_change_percentage_200d", "price_change_percentage_1y"]]) ##have to do fit_transform otherwise we see Scaler not transformed
## FORCES the numbers to be between 0 and 1 STANDARDIZATION and NORMALIZATION LOOK INTO normally distributed - wont get good results if dont normalize it

# %%
# Create a DataFrame with the scaled data
## best practice is to first check what type of data we have
type(scaled_data)
    ##https://stackoverflow.com/questions/35723472/how-to-use-sklearn-fit-transform-with-pandas-and-return-dataframe-instead-of-num
    ##scaled_features_df = pd.DataFrame(scaled_features, index=df.index, columns=df.columns)

# Copy the crypto names from the original data # Set the coinid column as index

scaled_data_df = pd.DataFrame(scaled_data, index=market_data_df.index, columns=market_data_df.columns)

# Display sample data
scaled_data_df.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11

    ## printing a natural
    ##number from 5 to 20 #for i in range(5, 20):print(i, end=" ") https://www.geeksforgeeks.org/python-range-function/
    #https://cs.stanford.edu/people/nick/py/python-range.html#:~:text=The%20most%20common%20form%20is,numbers%2C%20starting%20with%200%60

k_list= list(range(1, 11))

# Create an empty list to store the inertia values, 
    #this is crazy  xs = [] https://stackoverflow.com/questions/10712002/create-an-empty-list-with-certain-size-in-python
     #which is an empty list 

inertia_list=[]

# Create a for loop to compute the inertia with each possible value of k 
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using the scaled DataFrame
# 3. Append the model.inertia_ to the inertia list

    ## - READ UP ON K MEANS
    ##see Xpert learn ´´´ 
            # # Step 1: Read the data and create a DataFrame
            # data = pd.read_csv('stock_data.csv', parse_dates=['date'], infer_datetime_format=True)
            # data.set_index('date', inplace=True)

            # # Step 2: Define the range of k-values
            # k_values = list(range(1, 11))

            # # Step 3: Create an empty list to store inertia values
            # inertia_values = []

            # # Step 4: Iterate over each k-value, fit K-means model, and calculate inertia
            # for k in k_values:
            #     kmeans = KMeans(n_clusters=k)
            #     kmeans.fit(data)
            #     inertia_values.append(kmeans.inertia_)

            # # Step 5: Print or use the inertia values as needed
            # print(inertia_values)
            # You can run this code in a Python environment after reading in the stock_data.csv file to compute the inertia for each possible value of k.
            # ´´´


## THEY LOVE THIS QUESTION IN INTERVIEWS- GIVE US AN AN EXAMPLE OF A UNSUPERVISED LEARNING ---talk about Kmeans and class algorithm 
for k in k_list:
    kmeans = KMeans(n_clusters=k, n_init='auto', random_state=1) ## gives same initial groups everytime... want my answer to be same as Instructor
    kmeans.fit(scaled_data_df)
    inertia_list.append(kmeans.inertia_)



# Create a dictionary with the data to plot the Elbow curve  first look at the list inertia_list then Xpert learn 
## {} is a dictitionary with k being the key and interia being the value

elbow_data = {
    "k": k_list,
    "inertia": inertia_list
}
# Create a DataFrame with the data to plot the Elbow curve
elbow_data_df = pd.DataFrame(elbow_data)

# Display the DataFrame
elbow_data_df
# Out:
#     k     inertia
# 0   1  287.000000
# 1   2  212.123342
# 2   3  165.136752
# 3   4   79.022435
# 4   5   66.413051
# 5   6   61.634088
# 6   7   46.074467
# 7   8   43.392694
# 8   9   32.913223
# 9  10   30.469111

# %%
# Plot a line chart with all the inertia values computed with 
    ## assistance by Tutor: Paddington and TA: Rythmn
        # import matplotlib.pyplot as plt
        # plt.figure(figsize=(10, 6))
        # plt.plot(elbow_data_df["k"], elbow_data_df["inertia"], marker='o', color='b', linestyle='-', linewidth=2)
        # #the different values of k to visually identify the optimal value for k.
        # ## This doesnt look like an elbow curve so doing it again see next line attempt 2

# %%
# Attempt 2- Plot a line chart with all the inertia values computed with 

elbow_data_curve=elbow_data_df.hvplot.line(
    x="k", 
    y="inertia", 
    title="Elbow Curve", 
    xticks=k
)
elbow_data_curve
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
# **Question:** What is the best value for `k`?
#
# **Answer:**

# %% [markdown]
# The best value for K is 4.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled Data.

# %%
# Initialize the K-Means model using the best value for k

    # Notes from Xpert Learnd 
        # To initialize the K-Means model using the best value for k, you can use the following code snippet:
        # from sklearn.cluster import KMeans
            # # Define the best value for k
            # best_k = 3    
            # # Initialize the K-Means model with the best value for k
            # kmeans_model = KMeans(n_clusters=best_k, n_init='auto', random_state=0)
            # This code initializes a K-Means model with the best value for k, which in this case is 3. You can adjust the best_k variable to the optimal number of clusters determined using the elbow method or any other method

## CLUSTERS IS 4 NOW THAT I KNOW 
k1_model= KMeans(n_clusters=4, n_init='auto',random_state=1)

# %%
# Fit the K-Means model using the scaled data
## just taking the k value and trying to fit the k means
k1_model.fit(scaled_data_df)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data

clusters = k1_model.predict(scaled_data_df)
# View the resulting array of cluster values.
clusters
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 3, 2, 0, 0, 1, 0, 0, 0, 0],
#       dtype=int32)

# %%
# Create a copy of the DataFrame
predicited_scaled_data =scaled_data_df.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
# error with predicited_scaled_data["Predicted Clusters"] = predicited_scaled_data
        #It seems there was an error when trying to add a new column to the DataFrame with the predicted clusters. The error message indicates that you cannot set a DataFrame with multiple columns to a single column.
                # To add a new column with the predicted clusters to the DataFrame, you need to specify the actual predicted cluster values instead of the entire DataFrame. Here's the corrected code snippet:
                # # Add a new column to the DataFrame with the predicted clusters
                # predicited_scaled_data["Predicted Clusters"] = predicted_clusters

                # # Display sample data
                # predicited_scaled_data.head()
                # Make sure predicted_clusters contains the predicted cluster values that you want to assign to the new column "Predicted Clusters" in the DataFrame predicited_scaled_data.

predicited_scaled_data["Predicted Clusters"] = clusters
# Display sample data
predicited_scaled_data.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using Pandas plot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Use "rainbow" for the color to better visualize the data.

scatter_pca_predictions= predicited_scaled_data.hvplot.scatter(
    title= "Price Change 24h vs 7d",
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    c="Predicted Clusters",
    colormap="rainbow"
  
)
scatter_pca_predictions
# Out:
# :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,Predicted Clusters)

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)
pca
# Out:
# PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` on the ORIGINAL scaled DataFrame to reduce to three principal components.
## transforming means look at number of columns example we had 10 columns and now we want to move to 3 for examples 
### THIS IS MOVING IT FROM AN XYZ TO XY PLANE !! for example 10 dimensions to a 3 column features all in xy plane 
##### HUGE MISTAKE MADED___ DATA LEAK BY USING ANSWERS TO PREDICT BECAUSE I WASNT USING THE ORIGINAL DATA I WAS USING PREDICTED SCALED DATA WITH EXTRA COLUMNS 


pca_df = pca.fit_transform(scaled_data_df)

# View the first five rows of the DataFrame. 
## at first I was thinking it was this pca_df.head(5) but not so we want to see first 5 rows 
pca_df[0:5]
# Out:
# array([[-0.60066733,  0.84276006,  0.46159457],
#        [-0.45826071,  0.45846566,  0.95287678],
#        [-0.43306981, -0.16812638, -0.64175193],
#        [-0.47183495, -0.22266008, -0.47905316],
#        [-1.15779997,  2.04120919,  1.85971527]])

# %%
# Retrieve the explained variance to determine how much information  can be attributed to each principal component.

    ##To retrieve the explained variance of each principal component in Python after performing Principal Component Analysis (PCA), you can use the explained_variance_ratio_ attribute of the PCA model. Here is an example code snippet to get the explained variance of each principal component:
        # # Assuming you have already performed PCA and stored the PCA model in a variable named 'pca_model'
        # explained_variance = pca_model.explained_variance_ratio_
        # print(explained_variance)
##EXAMPLE 65% of data that was originally in the 10 columns when you move from 10 to 3 you lose 35% of data in the first dimention 
pca.explained_variance_ratio_
# Out:
# array([0.3719856 , 0.34700813, 0.17603793])

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:**
# pca.explained_variance_ratio_.sum() so answer is 0.8950316570309842

# %% [markdown]
# To answer this question we need to find the sum using the code pca.explained_variance_ratio_.sum()
# see below. The total explained variance is 90.93% (round up two decimals).

# %%
#THIS IS HOW MUCH OF THE ORIGINAL DATA THAT WAS RETAINED SO LOST ABOUT 9% of the DATA -PCA, PCL , LDA ARE  FEATURE REDUCTION TECHNIQUES INTERVIEW QUESTION
pca.explained_variance_ratio_.sum()
# Out:
# 0.8950316570309842

# %%
# Create a new DataFrame with the PCA data.
# Note: The code for this step is provided for you
import pandas as pd #Per Xpert learn to resolve issue with hplot and pandas not being read properly 
# Creating a DataFrame with the PCA data
pca_data= pd.DataFrame(
    pca_df,
    columns =["PC1", "PC2", "PC3"])

# Copy the crypto names from the ORIGINAL DATA
pca_data["coin_id"]=scaled_data_df.index

# Set the coinid column as index
pca_data=pca_data.set_index("coin_id")

# Display sample data
pca_data.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values to try
# Use a range from 1 to 11
k2_list= list(range(1,11))

# Create an empty list to store the inertia values
inertia2_list= []
# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
# 2. Fit the model to the data using PCA DataFrame.
# 3. Append the model.inertia_ to the inertia list

for k2 in k2_list:
    kmeans = KMeans(n_clusters=k2, n_init='auto', random_state=1)
    kmeans.fit(pca_data)
    inertia2_list.append(kmeans.inertia_)


# Create a dictionary with the data to plot the Elbow curve
elbow_data2= {
    "k2": k2_list,
    "inertia 2": inertia2_list
}

# Create a DataFrame with the data to plot the Elbow curve
elbow_data2_df = pd.DataFrame(elbow_data2)

# Display the DataFrame
elbow_data2_df
# Out:
#    k2   inertia 2
# 0   1  256.874086
# 1   2  182.339530
# 2   3  135.442408
# 3   4   49.665497
# 4   5   38.672582
# 5   6   34.507577
# 6   7   23.728365
# 7   8   18.574523
# 8   9   15.572672
# 9  10   11.407667

# %%
# Plot a line chart with all the inertia values computed with 
import hvplot.pandas
elbow_data2 = elbow_data2_df.hvplot.line(
    x="k2", 
    y="inertia 2", 
    title="Elbow Curve 2", 
    xticks=k2
)
elbow_data2
# the different values of k to visually identify the optimal value for k.
# Out:
# :Curve   [k2]   (inertia 2)

# %% [markdown]
# #### Answer the following questions:
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer: 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer: no

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
## THE FIRST TIME WE WERE USING KMEANS THE SECOND TIME WE WERE USING KMEANS WITH PCS 
### k1_model= KMeans(n_clusters=4, n_init='auto',random_state=1) changed to k2 

k2_model= KMeans(n_clusters=4, n_init='auto',random_state=1)

# %%
# Fit the K-Means model using the PCA data

k2_model.fit(pca_data)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
        # COPIED # Predict the clusters to group the cryptocurrencies using the scaled data
        # clusters = k1_model.predict(scaled_data_df)
        # # View the resulting array of cluster values.
        # clusters

clusters2 = k2_model.predict(pca_data)
clusters2

# Print the resulting array of cluster values.
# Out:
# array([2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 3, 2, 0, 0, 1, 0, 0, 0, 0],
#       dtype=int32)

# %%
# Create a copy of the DataFrame with the PCA data

predicited_pca_data =pca_data.copy()
# Add a new column to the DataFrame with the predicted clusters

predicited_pca_data["Predicted Clusters"] = clusters2
# Display sample data
predicited_pca_data.head()
# Out:
#                    PC1       PC2       PC3  Predicted Clusters
# coin_id
# bitcoin      -0.600667  0.842760  0.461595                   2
# ethereum     -0.458261  0.458466  0.952877                   2
# tether       -0.433070 -0.168126 -0.641752                   0
# ripple       -0.471835 -0.222660 -0.479053                   0
# bitcoin-cash -1.157800  2.041209  1.859715                   2

# %%
# Create a scatter plot using hvPlot by setting `x="PCA1"` and `y="PCA2"`. 

scatter_pca_predictions= predicited_pca_data.hvplot.scatter(
    title= "Price Change 24h vs 7d",
    x="PC1",
    y="PC2",
    c="Predicted Clusters",
    colormap="rainbow"
  
)
scatter_pca_predictions
# Out:
# :Scatter   [PC1]   (PC2,Predicted Clusters)

# %% [markdown]
# ### Determine the Weights of Each Feature on each Principal Component

# %%
# Use the columns from the original scaled DataFrame as the index.
scaled_data_df.columns
    ##To use the columns from the original scaled DataFrame as the index, you can set the index of the DataFrame to those columns. Here's how you can do it:
    # # Assuming df_scaled is your original scaled DataFrame
    # df_scaled.set_index(['column1', 'column2'], inplace=True)
    # Replace 'column1' and 'column2' with the actual column names you want to use as the index. This will set the index of the DataFrame to those column
# FROM ABOVE LINES scaled_data_df = pd.DataFrame(scaled_data, index=market_data_df.index, columns=market_data_df.columns)


# DONT USE THIS scaled_data_df = scaled_data_df.T
#scaled_data_df.set_index(scaled_data_df.columns, inplace=True)

#scaled_data_df.set.index(['price_change_percentage_24h', 'price_change_percentage_7d',
    #  'price_change_percentage_14d', 'price_change_percentage_30d',
    #    'price_change_percentage_60d', 'price_change_percentage_200d',
    #    'price_change_percentage_1y']

# %%
# Assuming pca is your PCA object and scaled_data_df is your DataFrame after scaling and PCA
# Get the weights of each feature on each principal component
weights = pca.components_

# Create a DataFrame to show the weights of each feature for each principal component
weights_df = pd.DataFrame(weights, columns=scaled_data_df.columns)

# Display the DataFrame
print(weights_df)
# Out:
#    price_change_percentage_24h  price_change_percentage_7d  \
# 0                    -0.416728                   -0.102432
# 1                     0.358162                    0.227432
# 2                    -0.218795                    0.787670
#
#    price_change_percentage_14d  price_change_percentage_30d  \
# 0                    -0.009162                     0.191523
# 1                     0.540415                     0.562182
# 2                     0.349534                    -0.181744
#
#    price_change_percentage_60d  price_change_percentage_200d  \
# 0                     0.320365                      0.594468
# 1                     0.434040                      0.027735
# 2                    -0.361377                      0.039733
#
#    price_change_percentage_1y
# 0                    0.568379
# 1                   -0.150789
# 2                    0.210541

# %%
# To determine which features have the strongest positive or negative influence on each principal component, you would need to look at the weights of each feature for each principal component. By analyzing these weights, you can identify which features contribute the most to each principal component.

# If you have already created a DataFrame that shows the weights of each feature for each principal component, you can examine the values in this DataFrame to identify the features with the strongest positive or negative influence on each component.

# Features with higher positive weights have a stronger positive influence on the component, while features with higher negative weights have a stronger negative influence on the component. By comparing the weights across features for each principal component, you can determine which features are most influential in shaping that component.

# If you provide me with the specific weights for each feature on each principal component, I can help you analyze which features have the strongest positive or negative influence

# %% [markdown]
# #### Answer the following question:
#
# * **Question:** Which features have the strongest positive or negative influence on each component?
#
# * **Answer:**
# We can analyze which features have the strongest positive or negative influence on each component:
#
# Principal Component 0:
#
# Strongest positive influences: price_change_percentage_200d, price_change_percentage_1y
# Strongest negative influence: price_change_percentage_24h
#
# Principal Component 1:
#
# Strongest positive influences: price_change_percentage_7d, price_change_percentage_14d, price_change_percentage_30d, price_change_percentage_60d, price_change_percentage_200d
# Strongest negative influence: price_change_percentage_1y
#
# Principal Component 2:
#
# Strongest positive influences: price_change_percentage_7d, price_change_percentage_14d, price_change_percentage_1y
# Strongest negative influence: price_change_percentage_24h, price_change_percentage_30d, price_change_percentage_60d
